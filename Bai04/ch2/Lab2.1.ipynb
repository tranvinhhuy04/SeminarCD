# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv


load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

genai.configure(api_key=api_key)

if __name__ == "__main__":
    model = genai.GenerativeModel('gemini-2.5-flash')

  
    response = model.generate_content("What is the FizzBuzz problem ?")

   
    print("-" * 20)
    print("Gemini Response:", response.text)
    print("-" * 20)
# Out:
# --------------------
# Gemini Response: The **FizzBuzz problem** is a classic programming interview question, often used as a basic screening test to filter out candidates who cannot program at all.
#
# Here's how it works:
#
# **The Goal:**
# Write a program that prints numbers from 1 to 100. But for multiples of three print "Fizz" instead of the number and for the multiples of five print "Buzz". For numbers which are multiples of both three and five print "FizzBuzz".
#
# **The Rules:**
#
# 1.  **Iterate:** Go through numbers from 1 up to (and including) 100.
# 2.  **Multiples of 3 and 5:** If a number is divisible by *both* 3 and 5 (i.e., it's a multiple of 15), print "FizzBuzz".
# 3.  **Multiples of 3:** If a number is divisible by 3 but *not* by 5, print "Fizz".
# 4.  **Multiples of 5:** If a number is divisible by 5 but *not* by 3, print "Buzz".
# 5.  **Otherwise:** If a number is not divisible by either 3 or 5, print the number itself.
#
# **Example Output (first few numbers):**
#
# 1
# 2
# Fizz (for 3)
# 4
# Buzz (for 5)
# Fizz (for 6)
# 7
# 8
# Fizz (for 9)
# Buzz (for 10)
# 11
# Fizz (for 12)
# 13
# 14
# FizzBuzz (for 15)
# ... and so on, up to 100.
#
# **Why is it used?**
#
# *   **Basic Programming Concepts:** It tests fundamental understanding of loops, conditional statements (`if`, `else if`, `else`), and the modulo operator (`%`) for checking divisibility.
# *   **Logical Thinking:** It requires thinking about the order of conditions (e.g., checking for "FizzBuzz" *before* checking for just "Fizz" or "Buzz" is crucial to avoid incorrect output).
# *   **Simple Filter:** While seemingly trivial, a surprising number of aspiring programmers struggle to solve FizzBuzz correctly, indicating a lack of basic problem-solving skills or understanding of programming syntax. It's an effective way to quickly identify candidates who lack even rudimentary coding abilities.
# --------------------
